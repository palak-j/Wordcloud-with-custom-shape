# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud
import pickle

from PIL import Image

# %%
# Read input file. Here, it is in the pickle format

with open('vehicle.p', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
#                 id   region  price  year manufacturer  \
# 27      7316814884   auburn  33590  2014          gmc
# 28      7316814758   auburn  22590  2010    chevrolet
# 29      7316814989   auburn  39590  2020    chevrolet
# 30      7316743432   auburn  30990  2017       toyota
# 31      7316356412   auburn  15000  2013         ford
# ...            ...      ...    ...   ...          ...
# 426875  7301591192  wyoming  23590  2019       nissan
# 426876  7301591187  wyoming  30590  2020        volvo
# 426877  7301591147  wyoming  34990  2020     cadillac
# 426878  7301591140  wyoming  28990  2018        lexus
# 426879  7301591129  wyoming  30590  2019          bmw
#
#                            model  condition title_status  odometer       size  \
# 27      sierra 1500 crew cab slt       good        clean   57923.0         na
# 28                silverado 1500       good        clean   71229.0         na
# 29           silverado 1500 crew       good        clean   19160.0         na
# 30          tundra double cab sr       good        clean   41124.0         na
# 31                     f-150 xlt  excellent        clean  128000.0  full-size
# ...                          ...        ...          ...       ...        ...
# 426875         maxima s sedan 4d       good        clean   32226.0         na
# 426876  s60 t5 momentum sedan 4d       good        clean   12029.0         na
# 426877          xt4 sport suv 4d       good        clean    4174.0         na
# 426878           es 350 sedan 4d       good        clean   30112.0         na
# 426879  4 series 430i gran coupe       good        clean   22716.0         na
#
#              type state  post_year post_month post_date
# 27         pickup    al       2021         05        04
# 28         pickup    al       2021         05        04
# 29         pickup    al       2021         05        04
# 30         pickup    al       2021         05        04
# 31          truck    al       2021         05        03
# ...           ...   ...        ...        ...       ...
# 426875      sedan    wy       2021         04        04
# 426876      sedan    wy       2021         04        04
# 426877  hatchback    wy       2021         04        04
# 426878      sedan    wy       2021         04        04
# 426879      coupe    wy       2021         04        04
#
# [247994 rows x 15 columns]

# %%
# Read image as masked format (Wordcloud will be in the shape of this image)

mask = np.array(Image.open('car.jpg'))

# %%
# Take data for wordcloud (here, we are taking all the manufacturers from the vehicle data)
text = ' '.join(data['manufacturer'].tolist())

# %%
# Create wordcloud 
wordcloud = WordCloud(width = 7000, height = 5000, random_state=1, prefer_horizontal=1,background_color='white', contour_color='cornflowerblue', colormap='Set2', contour_width=4, collocations=True, mask=mask).generate(text)

# %%
# parameters of the plot

plt.figure(figsize=(20, 10))
plt.imshow(wordcloud) 
plt.tight_layout(pad=0)
plt.axis("off");
